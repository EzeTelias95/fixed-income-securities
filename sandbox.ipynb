# %%
from models.FixedIncomeInstruments.Bullet import Bullet

bullet = Bullet(maturity_date='2025-01-01',issue_date='2020-01-01', principal=1000, interest_rate=0.05, annual_compound=2)

df = bullet.discounted_cashflows()
df

# %%
import datetime
bullet.price(valuation_date=datetime.date(2022,7,1))

# %%
print(bullet.future_value())
print(bullet.future_value(start_date=datetime.date(2022,7,1)))

# %%
bullet.yield_to_maturity()
